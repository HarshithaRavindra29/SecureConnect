# %%
#pip install nudenet
#pip install tensorflow==1.8.0

# %%
from nudenet import NudeClassifier
classifier = NudeClassifier()
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !wget https://previews.123rf.com/images/nickp37/nickp371210/nickp37121000025/15563580-attractive-shirtless-man-studio-shot-over-white-.jpg
# Out:
# --2020-04-19 19:40:56--  https://previews.123rf.com/images/nickp37/nickp371210/nickp37121000025/15563580-attractive-shirtless-man-studio-shot-over-white-.jpg
# Resolving previews.123rf.com (previews.123rf.com)... 184.84.61.93
# Connecting to previews.123rf.com (previews.123rf.com)|184.84.61.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84558 (83K) [image/jpeg]
# Saving to: ‘15563580-attractive-shirtless-man-studio-shot-over-white-.jpg’
#
# 15563580-attractive 100%[===================>]  82.58K  --.-KB/s    in 0.03s
#
# 2020-04-19 19:40:56 (3.08 MB/s) - ‘15563580-attractive-shirtless-man-studio-shot-over-white-.jpg’ saved [84558/84558]

# %%
# !wget https://webgazer.cs.brown.edu/media/people/alexpap.jpg

# %%
classifier.classify('alexpap.jpg')
# Out:
# {'alexpap.jpg': {'safe': 0.99500906, 'unsafe': 0.004990972}}

# %%
classifier.classify('15563580-attractive-shirtless-man-studio-shot-over-white-.jpg')
# Out:
# {'15563580-attractive-shirtless-man-studio-shot-over-white-.jpg': {'safe': 0.13878998,
#   'unsafe': 0.86121005}}
